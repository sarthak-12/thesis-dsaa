# %% [markdown]
# # LSTM-BERT model

# %% [markdown]
# # Relevant Imports

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
import re
import string
from sentence_transformers import SentenceTransformer
import nltk

# %% [markdown]
# # Check for MPS backend

# %%
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# # Preprocessing

# %%
filepath_num = '../../code_final/GARCH/GARCH_output.csv'
filepath_sent = '../../dataset_final/FinSen_S&P500/FinSen_text_annotated.csv'

data_num = pd.read_csv(filepath_num)
data_sent = pd.read_csv(filepath_sent)

# %%
data_sent.head()
# Out:
#    Unnamed: 0                                  Title           Tag  \
# 0           0  TSX Slightly Down, Books Weekly Gains  Stock Market
# 1           1          UnitedHealth Hits 4-week High        stocks
# 2           2          Cisco Systems Hits 4-week Low        stocks
# 3           3                 AT&T Hits All-time Low        stocks
# 4           4             Microsoft Hits 4-week High        stocks
#
#          Time                                            Content  \
# 0  16/07/2023  TSX Slightly Down, Books Weekly GainsUnited St...
# 1  15/07/2023  UnitedHealth Hits 4-week HighUnited States sto...
# 2  15/07/2023  Cisco Systems Hits 4-week LowUnited States sto...
# 3  15/07/2023  AT&T Hits All-time LowUnited States stocksAT&T...
# 4  15/07/2023  Microsoft Hits 4-week HighUnited States stocks...
#
#    sentiment_score
# 0             0.13
# 1             0.62
# 2            -0.43
# 3            -0.28
# 4             0.60

# %% [markdown]
# ## Data Alignment

# %% [markdown]
# ### Text Data

# %%
import re
import nltk

# Download the sentence tokenizer only once
nltk.download("punkt_tab")  

from nltk.tokenize import sent_tokenize

# ----------------------------------------
# 1. Minimal cleaning function (unchanged)
# ----------------------------------------
def minimal_clean_text(text: str, to_lowercase: bool = False) -> str:
    """
    Minimal cleaning for transformer-based models:
    1. Remove HTML tags.
    2. Remove/replacing weird characters if needed.
    3. (Optional) Convert to lowercase if you're using an uncased model.
    """
    # 1. Remove HTML tags:
    text = re.sub(r'<.*?>', '', text)

    # 2. Remove or replace unwanted characters (non-ASCII -> space here):
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)

    # 3. (Optional) Lowercasing:
    if to_lowercase:
        text = text.lower()

    # Remove excessive whitespace
    text = " ".join(text.split())

    return text

# --------------------------------------------
# 2. Helper function: remove duplicate sentences
# --------------------------------------------
def remove_duplicate_sentences(text: str) -> str:
    """
    Splits the text into sentences (using NLTK), 
    then removes exact duplicate sentences. 
    Joins back with a space.
    """
    sentences = sent_tokenize(text)
    seen = set()
    unique_sentences = []
    
    for s in sentences:
        s = s.strip()
        if s not in seen:
            unique_sentences.append(s)
            seen.add(s)
            
    return " ".join(unique_sentences)

# ---------------------------------------------
# 3. Clean the content only (exclude the Title)
# ---------------------------------------------
data_sent['cleaned_content'] = data_sent['Content'].apply(
    lambda x: minimal_clean_text(x, to_lowercase=False)
)

# ---------------------------------------------
# 4. Remove duplicate sentences from each entry
# ---------------------------------------------
data_sent['cleaned_content'] = data_sent['cleaned_content'].apply(remove_duplicate_sentences)

# (The group-by and merging part has been removed)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/skhanna/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
data_sent = data_sent.rename(columns={'Time': 'Date'})

# %%
# Step 1: Parse day-first
data_sent['Date'] = pd.to_datetime(data_sent['Date'], dayfirst=True)
# 2. Sort by date in ascending order
data_sent.sort_values(by='Date', inplace=True)
data_sent.head()
# Out:
#        Unnamed: 0                                              Title  \
# 15533       15533  Blackstone boosts IPO after Beijing takes $3bn...
# 15532       15532              Trade Deficit Increases in March 2007
# 15530       15530  Consumer Price Index 2.6 percent higher than i...
# 15527       15527  Nonfarm payroll employment increased by 157,00...
# 15531       15531  U.S. Federal Reserve Kept Rates Unchanged at 5...
#
#                      Tag       Date  \
# 15533               News 2007-06-04
# 15532   Balance of Trade 2007-06-04
# 15530     Inflation Rate 2007-06-06
# 15527  Unemployment Rate 2007-06-06
# 15531      Interest Rate 2007-06-06
#
#                                                  Content  sentiment_score  \
# 15533  Blackstone boosts IPO after Beijing takes $3bn...             0.03
# 15532  Trade Deficit Increases in March 2007United St...             0.00
# 15530  Consumer Price Index 2.6 percent higher than i...             0.00
# 15527  Nonfarm payroll employment increased by 157,00...             0.01
# 15531  U.S. Federal Reserve Kept Rates Unchanged at 5...            -0.01
#
#                                          cleaned_content
# 15533  Blackstone boosts IPO after Beijing takes $3bn...
# 15532  Trade Deficit Increases in March 2007United St...
# 15530  Consumer Price Index 2.6 percent higher than i...
# 15527  Nonfarm payroll employment increased by 157,00...
# 15531  U.S. Federal Reserve Kept Rates Unchanged at 5...

# %%
data_sent.head(30)
# Out:
#        Unnamed: 0                                              Title  \
# 15533       15533  Blackstone boosts IPO after Beijing takes $3bn...
# 15532       15532              Trade Deficit Increases in March 2007
# 15530       15530  Consumer Price Index 2.6 percent higher than i...
# 15527       15527  Nonfarm payroll employment increased by 157,00...
# 15531       15531  U.S. Federal Reserve Kept Rates Unchanged at 5...
# 15529       15529  United States GDP Rises 0.6 percent in the fir...
# 15528       15528  United States Trade Balance Deficit Rises to $...
# 15526       15526          US Economy is expanding after Q1 slowdown
# 15525       15525  The Fed is widely expected to keep the benchma...
# 15524       15524       Consumer Confidence and Housing Weaken in US
# 15523       15523  Fed keeps the federal funds rate at 5-1/4 percent
# 15522       15522  U.S. ISM Services Index Reached 14-Month High ...
# 15521       15521        US June unemployment rate unchanged at 4.5%
# 15520       15520  U.S. Growth, Easing Inflation to Follow Fed `S...
# 15519       15519  US trade deficit increases to $60.0 billion in...
# 15518       15518                Fed chief acknowledges credit fears
# 15517       15517  Fed Says Expansion Is Hampered by Increasing C...
# 15516       15516                       US new-home sales slide 6.6%
# 15515       15515      U.S. Economy Grew at a 3.4% Annual Rate in Q2
# 15514       15514    US core inflation was up by 0.1 percent in June
# 15513       15513  U.S. Companies added the smallest number of jo...
# 15512       15512  US Federal Reserve keeps interest rates unchan...
# 15511       15511           Stock Markets Fall Worldwide! Recession?
# 15510       15510  Goldman Sachs fights back by putting $3 billio...
# 15509       15509    U.S. Trade Deficit Narrows in June to $58.1 Bln
# 15508       15508       U.S. Consumer Prices Rise Less Than Expected
# 15507       15507  Dow Jones recovers 300 points in the final 45 ...
# 15506       15506      Federal Reserve cuts interest rates by 50 bps
# 15505       15505         Stock Markets Rally After the Fed rate cut
# 15504       15504              Stocks rise as subprime concerns ease
#
#                      Tag       Date  \
# 15533               News 2007-06-04
# 15532   Balance of Trade 2007-06-04
# 15530     Inflation Rate 2007-06-06
# 15527  Unemployment Rate 2007-06-06
# 15531      Interest Rate 2007-06-06
# 15529    GDP Growth Rate 2007-06-06
# 15528   Balance of Trade 2007-06-06
# 15526    GDP Growth Rate 2007-06-21
# 15525      Interest Rate 2007-06-24
# 15524    GDP Growth Rate 2007-06-26
# 15523      Interest Rate 2007-06-28
# 15522               News 2007-07-05
# 15521  Unemployment Rate 2007-07-06
# 15520     Inflation Rate 2007-07-10
# 15519   Balance of Trade 2007-07-12
# 15518       Stock Market 2007-07-18
# 15517    GDP Growth Rate 2007-07-25
# 15516    GDP Growth Rate 2007-07-26
# 15515    GDP Growth Rate 2007-07-27
# 15514     Inflation Rate 2007-07-31
# 15513  Unemployment Rate 2007-08-01
# 15512      Interest Rate 2007-08-07
# 15511       Stock Market 2007-08-10
# 15510       Stock Market 2007-08-13
# 15509   Balance of Trade 2007-08-14
# 15508     Inflation Rate 2007-08-15
# 15507       Stock Market 2007-08-16
# 15506      Interest Rate 2007-08-17
# 15505       Stock Market 2007-08-18
# 15504       Stock Market 2007-08-20
#
#                                                  Content  sentiment_score  \
# 15533  Blackstone boosts IPO after Beijing takes $3bn...             0.03
# 15532  Trade Deficit Increases in March 2007United St...             0.00
# 15530  Consumer Price Index 2.6 percent higher than i...             0.00
# 15527  Nonfarm payroll employment increased by 157,00...             0.01
# 15531  U.S. Federal Reserve Kept Rates Unchanged at 5...            -0.01
# 15529  United States GDP Rises 0.6 percent in the fir...             0.02
# 15528  United States Trade Balance Deficit Rises to $...            -0.01
# 15526  US Economy is expanding after Q1 slowdownUnite...             0.03
# 15525  The Fed is widely expected to keep the benchma...             0.01
# 15524  Consumer Confidence and Housing Weaken in USUn...            -0.66
# 15523  Fed keeps the federal funds rate at 5-1/4 perc...             0.16
# 15522  U.S. ISM Services Index Reached 14-Month High ...             0.66
# 15521  US June unemployment rate unchanged at 4.5%Uni...            -0.02
# 15520  U.S. Growth, Easing Inflation to Follow Fed `S...             0.00
# 15519  US trade deficit increases to $60.0 billion in...            -0.02
# 15518  Fed chief acknowledges credit fearsUnited Stat...            -0.11
# 15517  Fed Says Expansion Is Hampered by Increasing C...            -0.20
# 15516  US new-home sales slide 6.6%United States GDP ...            -0.38
# 15515  U.S. Economy Grew at a 3.4% Annual Rate in Q2U...             0.34
# 15514  US core inflation was up by 0.1 percent in Jun...             0.00
# 15513  U.S. Companies added the smallest number of jo...            -0.15
# 15512  US Federal Reserve keeps interest rates unchan...             0.00
# 15511  Stock Markets Fall Worldwide! Recession?United...            -0.67
# 15510  Goldman Sachs fights back by putting $3 billio...            -0.20
# 15509  U.S. Trade Deficit Narrows in June to $58.1 Bl...            -0.23
# 15508  U.S. Consumer Prices Rise Less Than ExpectedUn...            -0.10
# 15507  Dow Jones recovers 300 points in the final 45 ...             0.01
# 15506  Federal Reserve cuts interest rates by 50 bpsU...             0.00
# 15505  Stock Markets Rally After the Fed rate cutUnit...             0.29
# 15504  Stocks rise as subprime concerns easeUnited St...            -0.05
#
#                                          cleaned_content
# 15533  Blackstone boosts IPO after Beijing takes $3bn...
# 15532  Trade Deficit Increases in March 2007United St...
# 15530  Consumer Price Index 2.6 percent higher than i...
# 15527  Nonfarm payroll employment increased by 157,00...
# 15531  U.S. Federal Reserve Kept Rates Unchanged at 5...
# 15529  United States GDP Rises 0.6 percent in the fir...
# 15528  United States Trade Balance Deficit Rises to $...
# 15526  US Economy is expanding after Q1 slowdownUnite...
# 15525  The Fed is widely expected to keep the benchma...
# 15524  Consumer Confidence and Housing Weaken in USUn...
# 15523  Fed keeps the federal funds rate at 5-1/4 perc...
# 15522  U.S. ISM Services Index Reached 14-Month High ...
# 15521  US June unemployment rate unchanged at 4.5%Uni...
# 15520  U.S. Growth, Easing Inflation to Follow Fed `S...
# 15519  US trade deficit increases to $60.0 billion in...
# 15518  Fed chief acknowledges credit fearsUnited Stat...
# 15517  Fed Says Expansion Is Hampered by Increasing C...
# 15516  US new-home sales slide 6.6%United States GDP ...
# 15515  U.S. Economy Grew at a 3.4% Annual Rate in Q2U...
# 15514  US core inflation was up by 0.1 percent in Jun...
# 15513  U.S. Companies added the smallest number of jo...
# 15512  US Federal Reserve keeps interest rates unchan...
# 15511  Stock Markets Fall Worldwide! Recession?United...
# 15510  Goldman Sachs fights back by putting $3 billio...
# 15509  U.S. Trade Deficit Narrows in June to $58.1 Bl...
# 15508  U.S. Consumer Prices Rise Less Than ExpectedUn...
# 15507  Dow Jones recovers 300 points in the final 45 ...
# 15506  Federal Reserve cuts interest rates by 50 bpsU...
# 15505  Stock Markets Rally After the Fed rate cutUnit...
# 15504  Stocks rise as subprime concerns easeUnited St...

# %% [markdown]
# ### Merging Data

# %%
if 'Unnamed: 0' in data_sent.columns:
    data_sent = data_sent.drop(columns=['Unnamed: 0'])
data_sent.head()
# Out:
#                                                    Title                Tag  \
# 15533  Blackstone boosts IPO after Beijing takes $3bn...               News
# 15532              Trade Deficit Increases in March 2007   Balance of Trade
# 15530  Consumer Price Index 2.6 percent higher than i...     Inflation Rate
# 15527  Nonfarm payroll employment increased by 157,00...  Unemployment Rate
# 15531  U.S. Federal Reserve Kept Rates Unchanged at 5...      Interest Rate
#
#             Date                                            Content  \
# 15533 2007-06-04  Blackstone boosts IPO after Beijing takes $3bn...
# 15532 2007-06-04  Trade Deficit Increases in March 2007United St...
# 15530 2007-06-06  Consumer Price Index 2.6 percent higher than i...
# 15527 2007-06-06  Nonfarm payroll employment increased by 157,00...
# 15531 2007-06-06  U.S. Federal Reserve Kept Rates Unchanged at 5...
#
#        sentiment_score                                    cleaned_content
# 15533             0.03  Blackstone boosts IPO after Beijing takes $3bn...
# 15532             0.00  Trade Deficit Increases in March 2007United St...
# 15530             0.00  Consumer Price Index 2.6 percent higher than i...
# 15527             0.01  Nonfarm payroll employment increased by 157,00...
# 15531            -0.01  U.S. Federal Reserve Kept Rates Unchanged at 5...

# %%
if 'Unnamed: 0' in data_num.columns:
    data_num = data_num.drop(columns=['Unnamed: 0'])
data_num.head()
# Out:
#          Date     Open    Close     High        Volume  \
# 0  2007-08-01  1455.18  1465.81  1468.38  5.256780e+09
# 1  2007-08-07  1467.61  1476.70  1488.30  4.909390e+09
# 2  2007-08-10  1453.08  1453.64  1462.02  5.345780e+09
# 3  2007-08-13  1453.42  1452.92  1466.29  3.696280e+09
# 4  2007-08-14  1452.86  1426.54  1456.73  3.814630e+09
#
#    aggregate_sentiment_score  Movement  Daily_Return  Volatility  \
# 0                      -0.15         0      0.724264    1.257202
# 1                       0.00         1      0.742934    1.384401
# 2                      -0.67         0     -1.561590    1.159805
# 3                      -0.20         0     -0.049531    0.942009
# 4                      -0.23         0     -1.815654    1.229445
#
#    sentiment_volatility  ...  garch_residuals_lag7  rolling_cond_variance_3  \
# 0              0.270222  ...                   NaN                      NaN
# 1              0.262336  ...                   NaN                      NaN
# 2              0.367736  ...                   NaN                 1.423092
# 3              0.275372  ...                   NaN                 1.371807
# 4              0.250898  ...                   NaN                 1.480917
#
#    rolling_cond_volatility_3  rolling_residuals_3  rolling_cond_variance_5  \
# 0                        NaN                  NaN                      NaN
# 1                        NaN                  NaN                      NaN
# 2                   1.192399            -0.037356                      NaN
# 3                   1.170432            -0.294422                      NaN
# 4                   1.215417            -1.151931                 1.438991
#
#    rolling_cond_volatility_5  rolling_residuals_5  rolling_cond_variance_7  \
# 0                        NaN                  NaN                      NaN
# 1                        NaN                  NaN                      NaN
# 2                        NaN                  NaN                      NaN
# 3                        NaN                  NaN                      NaN
# 4                   1.198351             -0.39879                      NaN
#
#    rolling_cond_volatility_7  rolling_residuals_7
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
#
# [5 rows x 45 columns]

# %%
# Merge on the 'date' column, keeping only dates present in both dataframes
data_num['Date'] = pd.to_datetime(data_num['Date'])
merged_df = pd.merge(data_num, data_sent, on='Date', how='inner')

merged_df.head()
# Out:
#         Date     Open    Close     High        Volume  \
# 0 2007-08-01  1455.18  1465.81  1468.38  5.256780e+09
# 1 2007-08-07  1467.61  1476.70  1488.30  4.909390e+09
# 2 2007-08-10  1453.08  1453.64  1462.02  5.345780e+09
# 3 2007-08-13  1453.42  1452.92  1466.29  3.696280e+09
# 4 2007-08-14  1452.86  1426.54  1456.73  3.814630e+09
#
#    aggregate_sentiment_score  Movement  Daily_Return  Volatility  \
# 0                      -0.15         0      0.724264    1.257202
# 1                       0.00         1      0.742934    1.384401
# 2                      -0.67         0     -1.561590    1.159805
# 3                      -0.20         0     -0.049531    0.942009
# 4                      -0.23         0     -1.815654    1.229445
#
#    sentiment_volatility  ...  rolling_cond_volatility_5  rolling_residuals_5  \
# 0              0.270222  ...                        NaN                  NaN
# 1              0.262336  ...                        NaN                  NaN
# 2              0.367736  ...                        NaN                  NaN
# 3              0.275372  ...                        NaN                  NaN
# 4              0.250898  ...                   1.198351             -0.39879
#
#    rolling_cond_variance_7  rolling_cond_volatility_7  rolling_residuals_7  \
# 0                      NaN                        NaN                  NaN
# 1                      NaN                        NaN                  NaN
# 2                      NaN                        NaN                  NaN
# 3                      NaN                        NaN                  NaN
# 4                      NaN                        NaN                  NaN
#
#                                                Title                Tag  \
# 0  U.S. Companies added the smallest number of jo...  Unemployment Rate
# 1  US Federal Reserve keeps interest rates unchan...      Interest Rate
# 2           Stock Markets Fall Worldwide! Recession?       Stock Market
# 3  Goldman Sachs fights back by putting $3 billio...       Stock Market
# 4    U.S. Trade Deficit Narrows in June to $58.1 Bln   Balance of Trade
#
#                                              Content  sentiment_score  \
# 0  U.S. Companies added the smallest number of jo...            -0.15
# 1  US Federal Reserve keeps interest rates unchan...             0.00
# 2  Stock Markets Fall Worldwide! Recession?United...            -0.67
# 3  Goldman Sachs fights back by putting $3 billio...            -0.20
# 4  U.S. Trade Deficit Narrows in June to $58.1 Bl...            -0.23
#
#                                      cleaned_content
# 0  U.S. Companies added the smallest number of jo...
# 1  US Federal Reserve keeps interest rates unchan...
# 2  Stock Markets Fall Worldwide! Recession?United...
# 3  Goldman Sachs fights back by putting $3 billio...
# 4  U.S. Trade Deficit Narrows in June to $58.1 Bl...
#
# [5 rows x 50 columns]

# %%
merged_df.value_counts
# Out:
# <bound method DataFrame.value_counts of             Date     Open    Close     High        Volume  \
# 0     2007-08-01  1455.18  1465.81  1468.38  5.256780e+09
# 1     2007-08-07  1467.61  1476.70  1488.30  4.909390e+09
# 2     2007-08-10  1453.08  1453.64  1462.02  5.345780e+09
# 3     2007-08-13  1453.42  1452.92  1466.29  3.696280e+09
# 4     2007-08-14  1452.86  1426.54  1456.73  3.814630e+09
# ...          ...      ...      ...      ...           ...
# 15230 2023-07-14  4514.60  4505.41  4527.75  3.647450e+09
# 15231 2023-07-14  4514.60  4505.41  4527.75  3.647450e+09
# 15232 2023-07-14  4514.60  4505.41  4527.75  3.647450e+09
# 15233 2023-07-14  4514.60  4505.41  4527.75  3.647450e+09
# 15234 2023-07-14  4514.60  4505.41  4527.75  3.647450e+09
#
#        aggregate_sentiment_score  Movement  Daily_Return  Volatility  \
# 0                          -0.15         0      0.724264    1.257202
# 1                           0.00         1      0.742934    1.384401
# 2                          -0.67         0     -1.561590    1.159805
# 3                          -0.20         0     -0.049531    0.942009
# 4                          -0.23         0     -1.815654    1.229445
# ...                          ...       ...           ...         ...
# 15230                       2.04         1     -0.102660    0.570903
# 15231                       2.04         1     -0.102660    0.570903
# 15232                       2.04         1     -0.102660    0.570903
# 15233                       2.04         1     -0.102660    0.570903
# 15234                       2.04         1     -0.102660    0.570903
#
#        sentiment_volatility  ...  rolling_cond_volatility_5  \
# 0                  0.270222  ...                        NaN
# 1                  0.262336  ...                        NaN
# 2                  0.367736  ...                        NaN
# 3                  0.275372  ...                        NaN
# 4                  0.250898  ...                   1.198351
# ...                     ...  ...                        ...
# 15230              1.228589  ...                   0.815138
# 15231              1.228589  ...                   0.815138
# 15232              1.228589  ...                   0.815138
# 15233              1.228589  ...                   0.815138
# 15234              1.228589  ...                   0.815138
#
#        rolling_residuals_5  rolling_cond_variance_7  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                 -0.39879                      NaN
# ...                    ...                      ...
# 15230              0.42092                 0.671166
# 15231              0.42092                 0.671166
# 15232              0.42092                 0.671166
# 15233              0.42092                 0.671166
# 15234              0.42092                 0.671166
#
#        rolling_cond_volatility_7  rolling_residuals_7  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# ...                          ...                  ...
# 15230                   0.818995             0.349801
# 15231                   0.818995             0.349801
# 15232                   0.818995             0.349801
# 15233                   0.818995             0.349801
# 15234                   0.818995             0.349801
#
#                                                    Title  \
# 0      U.S. Companies added the smallest number of jo...
# 1      US Federal Reserve keeps interest rates unchan...
# 2               Stock Markets Fall Worldwide! Recession?
# 3      Goldman Sachs fights back by putting $3 billio...
# 4        U.S. Trade Deficit Narrows in June to $58.1 Bln
# ...                                                  ...
# 15230                           Amazon Hits 43-week High
# 15231                                 DXY Approaches 100
# 15232               US Core PPI Rises Less than Expected
# 15233  Progressive earnings below expectations at 0.5...
# 15234    PepsiCo earnings above expectations at 2.09 USD
#
#                             Tag  \
# 0             Unemployment Rate
# 1                 Interest Rate
# 2                  Stock Market
# 3                  Stock Market
# 4              Balance of Trade
# ...                         ...
# 15230                    stocks
# 15231                  Currency
# 15232  Core Producer Prices MoM
# 15233                  Earnings
# 15234                  Earnings
#
#                                                  Content  sentiment_score  \
# 0      U.S. Companies added the smallest number of jo...            -0.15
# 1      US Federal Reserve keeps interest rates unchan...             0.00
# 2      Stock Markets Fall Worldwide! Recession?United...            -0.67
# 3      Goldman Sachs fights back by putting $3 billio...            -0.20
# 4      U.S. Trade Deficit Narrows in June to $58.1 Bl...            -0.23
# ...                                                  ...              ...
# 15230  Amazon Hits 43-week HighUnited States stocksAm...             0.74
# 15231  DXY Approaches 100United States CurrencyThe do...            -0.20
# 15232  US Core PPI Rises Less than ExpectedUnited Sta...             0.00
# 15233  Progressive earnings below expectations at 0.5...             0.01
# 15234  PepsiCo earnings above expectations at 2.09 US...             0.01
#
#                                          cleaned_content
# 0      U.S. Companies added the smallest number of jo...
# 1      US Federal Reserve keeps interest rates unchan...
# 2      Stock Markets Fall Worldwide! Recession?United...
# 3      Goldman Sachs fights back by putting $3 billio...
# 4      U.S. Trade Deficit Narrows in June to $58.1 Bl...
# ...                                                  ...
# 15230  Amazon Hits 43-week HighUnited States stocksAm...
# 15231  DXY Approaches 100United States CurrencyThe do...
# 15232  US Core PPI Rises Less than ExpectedUnited Sta...
# 15233  Progressive earnings below expectations at 0.5...
# 15234  PepsiCo earnings above expectations at 2.09 US...
#
# [15235 rows x 50 columns]>

# %%
merged_df.columns
# Out:
# Index(['Date', 'Open', 'Close', 'High', 'Volume', 'aggregate_sentiment_score',
#        'Movement', 'Daily_Return', 'Volatility', 'sentiment_volatility',
#        'sentiment_volatility_lag1', 'aggregate_sentiment_score_lag1',
#        'Close_lag1', 'High_lag1', 'Volume_lag1', 'Daily_Return_lag1',
#        'Volatility_lag1', 'Log_Return', 'garch_cond_variance',
#        'garch_cond_volatility', 'garch_residuals', 'garch_cond_variance_lag1',
#        'garch_cond_volatility_lag1', 'garch_residuals_lag1',
#        'garch_cond_variance_lag2', 'garch_cond_volatility_lag2',
#        'garch_residuals_lag2', 'garch_cond_variance_lag3',
#        'garch_cond_volatility_lag3', 'garch_residuals_lag3',
#        'garch_cond_variance_lag5', 'garch_cond_volatility_lag5',
#        'garch_residuals_lag5', 'garch_cond_variance_lag7',
#        'garch_cond_volatility_lag7', 'garch_residuals_lag7',
#        'rolling_cond_variance_3', 'rolling_cond_volatility_3',
#        'rolling_residuals_3', 'rolling_cond_variance_5',
#        'rolling_cond_volatility_5', 'rolling_residuals_5',
#        'rolling_cond_variance_7', 'rolling_cond_volatility_7',
#        'rolling_residuals_7', 'Title', 'Tag', 'Content', 'sentiment_score',
#        'cleaned_content'],
#       dtype='object')

# %%
merged_df['rolling_cond_volatility_3_lag1'] = merged_df['rolling_cond_variance_3'].shift(1)
merged_df['rolling_cond_volatility_5_lag1'] = merged_df['rolling_cond_variance_5'].shift(1)
merged_df.columns
# Out:
# Index(['Date', 'Open', 'Close', 'High', 'Volume', 'aggregate_sentiment_score',
#        'Movement', 'Daily_Return', 'Volatility', 'sentiment_volatility',
#        'sentiment_volatility_lag1', 'aggregate_sentiment_score_lag1',
#        'Close_lag1', 'High_lag1', 'Volume_lag1', 'Daily_Return_lag1',
#        'Volatility_lag1', 'Log_Return', 'garch_cond_variance',
#        'garch_cond_volatility', 'garch_residuals', 'garch_cond_variance_lag1',
#        'garch_cond_volatility_lag1', 'garch_residuals_lag1',
#        'garch_cond_variance_lag2', 'garch_cond_volatility_lag2',
#        'garch_residuals_lag2', 'garch_cond_variance_lag3',
#        'garch_cond_volatility_lag3', 'garch_residuals_lag3',
#        'garch_cond_variance_lag5', 'garch_cond_volatility_lag5',
#        'garch_residuals_lag5', 'garch_cond_variance_lag7',
#        'garch_cond_volatility_lag7', 'garch_residuals_lag7',
#        'rolling_cond_variance_3', 'rolling_cond_volatility_3',
#        'rolling_residuals_3', 'rolling_cond_variance_5',
#        'rolling_cond_volatility_5', 'rolling_residuals_5',
#        'rolling_cond_variance_7', 'rolling_cond_volatility_7',
#        'rolling_residuals_7', 'Title', 'Tag', 'Content', 'sentiment_score',
#        'cleaned_content', 'rolling_cond_volatility_3_lag1',
#        'rolling_cond_volatility_5_lag1'],
#       dtype='object')

# %%
# Columns we want to retain
columns_to_keep = ['Date','Open', 'Movement', 'sentiment_volatility_lag1', 'aggregate_sentiment_score_lag1',
       'Close_lag1', 'High_lag1', 'Volume_lag1', 'Daily_Return_lag1',
       'Volatility_lag1', 'garch_cond_variance_lag1',
       'garch_cond_volatility_lag1', 'garch_residuals_lag1', 'rolling_cond_volatility_3_lag1', 'rolling_cond_volatility_5_lag1','Title','cleaned_content']
merged_df = merged_df[columns_to_keep]
merged_df.head()
# Out:
#         Date     Open  Movement  sentiment_volatility_lag1  \
# 0 2007-08-01  1455.18         0                   0.268142
# 1 2007-08-07  1467.61         1                   0.270222
# 2 2007-08-10  1453.08         0                   0.262336
# 3 2007-08-13  1453.42         0                   0.367736
# 4 2007-08-14  1452.86         0                   0.275372
#
#    aggregate_sentiment_score_lag1  Close_lag1  High_lag1   Volume_lag1  \
# 0                            0.00     1455.27    1488.30  4.524520e+09
# 1                           -0.15     1465.81    1468.38  5.256780e+09
# 2                            0.00     1476.70    1488.30  4.909390e+09
# 3                           -0.67     1453.64    1462.02  5.345780e+09
# 4                           -0.20     1452.92    1466.29  3.696280e+09
#
#    Daily_Return_lag1  Volatility_lag1  garch_cond_variance_lag1  \
# 0          -0.251552         0.991957                       NaN
# 1           0.724264         1.257202                  1.440581
# 2           0.742934         1.384401                  1.311621
# 3          -1.561590         1.159805                  1.517074
# 4          -0.049531         0.942009                  1.286727
#
#    garch_cond_volatility_lag1  garch_residuals_lag1  \
# 0                         NaN                   NaN
# 1                    1.200242              0.721654
# 2                    1.145260              0.740188
# 3                    1.231695             -1.573911
# 4                    1.134340             -0.049543
#
#    rolling_cond_volatility_3_lag1  rolling_cond_volatility_5_lag1  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                        1.423092                             NaN
# 4                        1.371807                             NaN
#
#                                                Title  \
# 0  U.S. Companies added the smallest number of jo...
# 1  US Federal Reserve keeps interest rates unchan...
# 2           Stock Markets Fall Worldwide! Recession?
# 3  Goldman Sachs fights back by putting $3 billio...
# 4    U.S. Trade Deficit Narrows in June to $58.1 Bln
#
#                                      cleaned_content
# 0  U.S. Companies added the smallest number of jo...
# 1  US Federal Reserve keeps interest rates unchan...
# 2  Stock Markets Fall Worldwide! Recession?United...
# 3  Goldman Sachs fights back by putting $3 billio...
# 4  U.S. Trade Deficit Narrows in June to $58.1 Bl...

# %%
merged_df.columns
# Out:
# Index(['Date', 'Open', 'Movement', 'sentiment_volatility_lag1',
#        'aggregate_sentiment_score_lag1', 'Close_lag1', 'High_lag1',
#        'Volume_lag1', 'Daily_Return_lag1', 'Volatility_lag1',
#        'garch_cond_variance_lag1', 'garch_cond_volatility_lag1',
#        'garch_residuals_lag1', 'rolling_cond_volatility_3_lag1',
#        'rolling_cond_volatility_5_lag1', 'Title', 'cleaned_content'],
#       dtype='object')

# %%
merged_df.value_counts
# Out:
# <bound method DataFrame.value_counts of             Date     Open  Movement  sentiment_volatility_lag1  \
# 0     2007-08-01  1455.18         0                   0.268142
# 1     2007-08-07  1467.61         1                   0.270222
# 2     2007-08-10  1453.08         0                   0.262336
# 3     2007-08-13  1453.42         0                   0.367736
# 4     2007-08-14  1452.86         0                   0.275372
# ...          ...      ...       ...                        ...
# 15230 2023-07-14  4514.60         1                   0.504529
# 15231 2023-07-14  4514.60         1                   0.504529
# 15232 2023-07-14  4514.60         1                   0.504529
# 15233 2023-07-14  4514.60         1                   0.504529
# 15234 2023-07-14  4514.60         1                   0.504529
#
#        aggregate_sentiment_score_lag1  Close_lag1  High_lag1   Volume_lag1  \
# 0                                0.00     1455.27    1488.30  4.524520e+09
# 1                               -0.15     1465.81    1468.38  5.256780e+09
# 2                                0.00     1476.70    1488.30  4.909390e+09
# 3                               -0.67     1453.64    1462.02  5.345780e+09
# 4                               -0.20     1452.92    1466.29  3.696280e+09
# ...                               ...         ...        ...           ...
# 15230                           -0.14     4510.04    4517.37  3.839530e+09
# 15231                           -0.14     4510.04    4517.37  3.839530e+09
# 15232                           -0.14     4510.04    4517.37  3.839530e+09
# 15233                           -0.14     4510.04    4517.37  3.839530e+09
# 15234                           -0.14     4510.04    4517.37  3.839530e+09
#
#        Daily_Return_lag1  Volatility_lag1  garch_cond_variance_lag1  \
# 0              -0.251552         0.991957                       NaN
# 1               0.724264         1.257202                  1.440581
# 2               0.742934         1.384401                  1.311621
# 3              -1.561590         1.159805                  1.517074
# 4              -0.049531         0.942009                  1.286727
# ...                  ...              ...                       ...
# 15230           0.847018         0.803948                  0.710618
# 15231           0.847018         0.803948                  0.710618
# 15232           0.847018         0.803948                  0.710618
# 15233           0.847018         0.803948                  0.710618
# 15234           0.847018         0.803948                  0.710618
#
#        garch_cond_volatility_lag1  garch_residuals_lag1  \
# 0                             NaN                   NaN
# 1                        1.200242              0.721654
# 2                        1.145260              0.740188
# 3                        1.231695             -1.573911
# 4                        1.134340             -0.049543
# ...                           ...                   ...
# 15230                    0.842982              0.843451
# 15231                    0.842982              0.843451
# 15232                    0.842982              0.843451
# 15233                    0.842982              0.843451
# 15234                    0.842982              0.843451
#
#        rolling_cond_volatility_3_lag1  rolling_cond_volatility_5_lag1  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                            1.423092                             NaN
# 4                            1.371807                             NaN
# ...                               ...                             ...
# 15230                        0.671256                        0.664923
# 15231                        0.671256                        0.664923
# 15232                        0.671256                        0.664923
# 15233                        0.671256                        0.664923
# 15234                        0.671256                        0.664923
#
#                                                    Title  \
# 0      U.S. Companies added the smallest number of jo...
# 1      US Federal Reserve keeps interest rates unchan...
# 2               Stock Markets Fall Worldwide! Recession?
# 3      Goldman Sachs fights back by putting $3 billio...
# 4        U.S. Trade Deficit Narrows in June to $58.1 Bln
# ...                                                  ...
# 15230                           Amazon Hits 43-week High
# 15231                                 DXY Approaches 100
# 15232               US Core PPI Rises Less than Expected
# 15233  Progressive earnings below expectations at 0.5...
# 15234    PepsiCo earnings above expectations at 2.09 USD
#
#                                          cleaned_content
# 0      U.S. Companies added the smallest number of jo...
# 1      US Federal Reserve keeps interest rates unchan...
# 2      Stock Markets Fall Worldwide! Recession?United...
# 3      Goldman Sachs fights back by putting $3 billio...
# 4      U.S. Trade Deficit Narrows in June to $58.1 Bl...
# ...                                                  ...
# 15230  Amazon Hits 43-week HighUnited States stocksAm...
# 15231  DXY Approaches 100United States CurrencyThe do...
# 15232  US Core PPI Rises Less than ExpectedUnited Sta...
# 15233  Progressive earnings below expectations at 0.5...
# 15234  PepsiCo earnings above expectations at 2.09 US...
#
# [15235 rows x 17 columns]>

# %%
merged_df.to_csv('multimodal_S&P500_all.csv')

# %% [markdown]
# ## Splitting Data
