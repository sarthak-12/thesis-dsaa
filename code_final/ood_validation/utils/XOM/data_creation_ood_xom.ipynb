# %% [markdown]
# # Relevant Imports

# %%
# Cell 1: Relevant Imports
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# # Preprocessing

# %%
# Cell 2: Load the CSV file
# Assuming the file is named 'sp500_news_simple_2024_AAPL.csv' and is in the current directory
df = pd.read_csv('sp500_news_simple_2024_XOM.csv')
# Display the first few rows to inspect the data
df.head()
# Out:
#         time_published                                              title  \
# 0  2024-01-02 12:05:00  3 Dimensional Mutual Funds for Consistent Returns
# 1  2024-01-02 12:20:33  ExxonMobil Reportedly Bids Iraq Farewell, Petr...
# 2  2024-01-02 13:00:00  Analysts Predict Surprising New 'Magnificent 7...
# 3  2024-01-02 13:00:07  Down 9% Since The Beginning Of 2023, What Shou...
# 4  2024-01-02 15:24:00  This Giant Oil Stock Is My Top Dividend Pick f...
#
#                                              summary
# 0  Below, we share with you three top-ranked Dime...
# 1  Exxon Mobil Corp XOM has reportedly exited the...
# 2  Forget the "Magnificent Seven" stocks that dro...
# 3  After a 9% decline since the beginning of 2023...
# 4  Exxon's strong dividends, its record of strong...

# %%
# Cell 3: Extract date from 'time_published' column without timestamp
# Convert 'time_published' to datetime format
df['time_published'] = pd.to_datetime(df['time_published'])
# Extract date in DD/MM/YYYY format
df['date'] = df['time_published'].dt.strftime('%d/%m/%Y')
# Display the updated DataFrame
df.head()
# Out:
#        time_published                                              title  \
# 0 2024-01-02 12:05:00  3 Dimensional Mutual Funds for Consistent Returns
# 1 2024-01-02 12:20:33  ExxonMobil Reportedly Bids Iraq Farewell, Petr...
# 2 2024-01-02 13:00:00  Analysts Predict Surprising New 'Magnificent 7...
# 3 2024-01-02 13:00:07  Down 9% Since The Beginning Of 2023, What Shou...
# 4 2024-01-02 15:24:00  This Giant Oil Stock Is My Top Dividend Pick f...
#
#                                              summary        date
# 0  Below, we share with you three top-ranked Dime...  02/01/2024
# 1  Exxon Mobil Corp XOM has reportedly exited the...  02/01/2024
# 2  Forget the "Magnificent Seven" stocks that dro...  02/01/2024
# 3  After a 9% decline since the beginning of 2023...  02/01/2024
# 4  Exxon's strong dividends, its record of strong...  02/01/2024

# %%
# Cell 4: Select only the required columns: date, title, and summary (assuming 'summary' is the content)
# Rename 'summary' to 'content' if needed for clarity
df_cleaned = df[['date', 'title', 'summary']].rename(columns={'summary': 'content'})
# Display the cleaned DataFrame
df_cleaned.head()
# Out:
#          date                                              title  \
# 0  02/01/2024  3 Dimensional Mutual Funds for Consistent Returns
# 1  02/01/2024  ExxonMobil Reportedly Bids Iraq Farewell, Petr...
# 2  02/01/2024  Analysts Predict Surprising New 'Magnificent 7...
# 3  02/01/2024  Down 9% Since The Beginning Of 2023, What Shou...
# 4  02/01/2024  This Giant Oil Stock Is My Top Dividend Pick f...
#
#                                              content
# 0  Below, we share with you three top-ranked Dime...
# 1  Exxon Mobil Corp XOM has reportedly exited the...
# 2  Forget the "Magnificent Seven" stocks that dro...
# 3  After a 9% decline since the beginning of 2023...
# 4  Exxon's strong dividends, its record of strong...

# %%
# Cell 5: Optional - Handle any missing values or duplicates if necessary
# Drop rows with missing values (if any)
df_cleaned = df_cleaned.dropna()
# Remove duplicates (if any)
df_cleaned = df_cleaned.drop_duplicates()
# Display info about the cleaned DataFrame
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1942 entries, 0 to 1948
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     1942 non-null   object
#  1   title    1942 non-null   object
#  2   content  1942 non-null   object
# dtypes: object(3)
# memory usage: 60.7+ KB

# %%
# Cell 6: Save the cleaned data to a new CSV file
output_filename = 'cleaned_sp500_news_2024_XOM.csv'
df_cleaned.to_csv(output_filename, index=False)
print(f"Cleaned data saved to {output_filename}")
# Out:
# Cleaned data saved to cleaned_sp500_news_2024_XOM.csv
